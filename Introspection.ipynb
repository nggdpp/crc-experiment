# %% [markdown]
# There are parts of the sample metadata in the CRC collections that should probably be related to other information sources. Values for geologic age and formation at depth should be associated with other subsurface geology data. Other sources of data may be tied to API well numbers. Operator names, well names, and field names may all be related to other sources as well. A look through current values in the CRC records shows evidence that they have been recorded often as a matter of course but not ever used for this kind of purpose (e.g., many alternate spellings of what is likely the same entity).
#
# This notebook uses the final assempled cores and cuttings collections stashed in MongoDB to work out the basic "dimensions" of the data for the concepts that might be most useful in linking to other related information but are in need of come cleanup.

# %%
from pymongo import MongoClient
import pandas as pd
import json

mongo_ndc = MongoClient()

# %% [markdown]
# We can get a fairly quick look at the unique values for each property of interest by leveraging groupby in Pandas. The following codeblock works through the main string value properties from both the CRC original data and the surficial geology reference we brought in from the geologic mapping unit amalgamation provided by Macrostrat. Field name, unique value, and number of occurrences go into a dataframe that I drop out to a CSV for further reference.

# %%
root_fields = {
    "_id": 0,
    "surface_age" : 1, 
    "gmu_name" : 1, 
    "strat_unit" : 1, 
    "Operator" : 1, 
    "Well Name" : 1, 
    "Field" : 1 
}

all_data = [i for i in mongo_ndc.crc.cores.find({},root_fields)]
all_data.extend([i for i in mongo_ndc.crc.cuttings.find({},root_fields)])

df_all_data = pd.DataFrame(all_data)

count_stats = list()
for field in [k for k in root_fields.keys() if k != "_id"]:
    count_stats.extend({"stat_field": field, "unique_value": x, "count": len(y)} for x, y in df_all_data.groupby(field))

pipeline = [
    {
        u"$unwind": {
            u"path": u"$intervals"
        }
    }, 
    {
        u"$project": {
            u"formation_from_crc": u"$intervals.Formation",
            u"age_from_crc": u"$intervals.Age",
            u"_id": 0
        }
    }
]

crc_age_formation = [i for i in mongo_ndc.crc.cores.aggregate(pipeline)]
crc_age_formation.extend([i for i in mongo_ndc.crc.cuttings.aggregate(pipeline)])

df_crc_age_formation = pd.DataFrame(crc_age_formation)
df_crc_age_formation = df_crc_age_formation.dropna(axis=0, how='any')

count_stats.extend({"stat_field": "formation_from_crc", "unique_value": x, "count": len(y)} for x, y in df_crc_age_formation.groupby("formation_from_crc"))
count_stats.extend({"stat_field": "age_from_crc", "unique_value": x, "count": len(y)} for x, y in df_crc_age_formation.groupby("age_from_crc"))

pipeline = [
    {
        u"$project": {
            u"surface_rocktype": 1.0
        }
    }, 
    {
        u"$unwind": {
            u"path": u"$surface_rocktype"
        }
    }
]

gmu_rocktype = [i for i in mongo_ndc.crc.cores.aggregate(pipeline)]
gmu_rocktype.extend([i for i in mongo_ndc.crc.cuttings.aggregate(pipeline)])

df_gmu_rocktype = pd.DataFrame(gmu_rocktype)

count_stats.extend({"stat_field": "surface_rocktype", "unique_value": x, "count": len(y)} for x, y in df_gmu_rocktype.groupby("surface_rocktype"))

df_count_stats = pd.DataFrame(count_stats)
df_count_stats.to_csv('crcwc_facets.csv')

# %%
df_count_stats.head()
# Out:
#     stat_field         unique_value  count
# 0  surface_age                          85
# 1  surface_age               Albian     37
# 2  surface_age  Albian - Cenomanian     23
# 3  surface_age    Anisian - Carnian     17
# 4  surface_age      Aptian - Albian      2

# %% [markdown]
# Here are the fields we pulled together for further examination, output to a crcwc_facets.csv file. Each of these comes with their own challenges in terms of the actual meaning/significance of the values to the wells in the CRC Well Catalog that will require some further thought.

# %%
for field_name, group in df_count_stats.groupby("stat_field"):
    print(field_name)
# Out:
# Field
# Operator
# Well Name
# age_from_crc
# formation_from_crc
# gmu_name
# strat_unit
# surface_age
# surface_rocktype

# %% [markdown]
# If we want to examine a particular property from the facets, we can slice the dataframe like this.

# %%
df_count_stats.loc[df_count_stats.stat_field == "surface_rocktype"]
# Out:
#              stat_field    unique_value  count
# 68623  surface_rocktype        alluvium   2111
# 68624  surface_rocktype     amphibolite     53
# 68625  surface_rocktype        andesite    392
# 68626  surface_rocktype       anhydrite     18
# 68627  surface_rocktype          aplite      2
# ...                 ...             ...    ...
# 68713  surface_rocktype            tuff    756
# 68714  surface_rocktype        volcanic   4288
# 68715  surface_rocktype  volcaniclastic     34
# 68716  surface_rocktype      wackestone      3
# 68717  surface_rocktype     welded tuff      1
#
# [95 rows x 3 columns]

# %% [markdown]
# One interesting area to examine that has a little bit of traction in terms of standardized vocabularies is lithology or rock type. Theoretically, we should be able to find all of the rock type values pulled in from the Macrostrat API against geologic mapping information in the GeoSciML lithology vocabulary. I initially took a crack at trying to work with the search services available through the [CGI GeoScience Vocabularies](http://resource.geosciml.org/classifier/cgi/lithology) but ran into some technical and performance problems, so I cached a derivation of the identifiers, labels, and definitions in a local file [lithology_vocab.json](lithology_vocab.json) just to demonstrate a point.
#
# Ultimately, I think we want individual collection owners and the NDC as a whole to be able to consult a whole set of managed ontologies on a regular basis to find alignment with concepts in source data. Alignment can be some type of direct connection between terms or a specified relationship to a concept in a vocabulary, potentially through an element of uncertainty if a search algorithim is used. As those relationships are built and expressed through the data, they form the basis for integration across disparate collections and new capabilities in search and discovery.
#
# As a simple example of this, I run through a process below to pull up the snapshot of the lithology vocabulary, check for alignment with the rock type terms in our CRC records, add the term URI to those that match, and show the results (53 matching, 42 not). To make this real, a more sophisticated search needs to be developed, hopefully against an established and programmable source for the vocabularies. Further discussion on the utility of this kind of vocabulary alignment work should help to prioritize efforts.

# %%
with open("lithology_vocab.json", "r") as f:
    lithology_vocab = json.load(f)
    f.close()

# %%
lithology_vocab[:5]
# Out:
# [{'uri': 'http://resource.geosciml.org/classifier/cgi/lithology/acidic_igneous_material',
#   'definition': 'Igneous material with more than 63 percent SiO2.',
#   'label': 'acidic igneous material'},
#  {'uri': 'http://resource.geosciml.org/classifier/cgi/lithology/acidic_igneous_rock',
#   'definition': 'Igneous rock with more than 63 percent SiO2.',
#   'label': 'acidic igneous rock'},
#  {'uri': 'http://resource.geosciml.org/classifier/cgi/lithology/alkali-olivine_basalt',
#   'definition': 'Alkali olivine basalt is silica-undersaturated, characterized by the absence of orthopyroxene, absence of quartz, presence of olivine, and typically contains some feldspathoid mineral, alkali feldspar or phlogopite in the groundmass. Feldspar phenocrysts typically are labradorite to andesine in composition. Augite is rich in titanium compared to augite in tholeiitic basalt. Alkali olivine basalt is relatively rich in sodium.',
#   'label': 'alkali olivine basalt'},
#  {'uri': 'http://resource.geosciml.org/classifier/cgi/lithology/alkali_feldspar_granite',
#   'definition': 'Granitic rock that has a plagioclase to total feldspar ratio less than 0.1. QAPF field 2.',
#   'label': 'alkali feldspar granite'},
#  {'uri': 'http://resource.geosciml.org/classifier/cgi/lithology/alkali_feldspar_rhyolite',
#   'definition': 'Rhyolitoid in which the ratio of plagioclase to total feldspar is less than 0.1. QAPF field 2.',
#   'label': 'alkali feldspar rhyolite'}]

# %%
def lookup_rock_type(label):
    return next((i["uri"] for i in lithology_vocab if i["label"] == label), None)

# %%
df_count_stats["term_uri"] = df_count_stats.apply(lambda x: lookup_rock_type(x["unique_value"]), axis=1)

# %%
df_count_stats.loc[(df_count_stats.stat_field == "surface_rocktype") & (df_count_stats.term_uri.notnull())]
# Out:
#              stat_field      unique_value  count  \
# 68624  surface_rocktype       amphibolite     53
# 68625  surface_rocktype          andesite    392
# 68627  surface_rocktype            aplite      2
# 68628  surface_rocktype           arenite     92
# 68632  surface_rocktype            basalt     43
# 68633  surface_rocktype           breccia     39
# 68635  surface_rocktype             chalk     83
# 68637  surface_rocktype              clay   4229
# 68638  surface_rocktype         claystone  11592
# 68639  surface_rocktype              coal   8047
# 68641  surface_rocktype      conglomerate  12505
# 68643  surface_rocktype            dacite     18
# 68645  surface_rocktype        diamictite     43
# 68646  surface_rocktype           diorite     13
# 68647  surface_rocktype          dolomite     87
# 68650  surface_rocktype         evaporite     44
# 68652  surface_rocktype            gabbro      3
# 68654  surface_rocktype            gneiss     67
# 68655  surface_rocktype        grainstone      3
# 68656  surface_rocktype           granite    221
# 68657  surface_rocktype      granodiorite     37
# 68658  surface_rocktype            gravel   4583
# 68666  surface_rocktype            latite      6
# 68667  surface_rocktype           lignite   5387
# 68668  surface_rocktype         limestone   5494
# 68671  surface_rocktype            marble     19
# 68675  surface_rocktype         migmatite      7
# 68676  surface_rocktype      monzogranite      7
# 68677  surface_rocktype         monzonite     30
# 68678  surface_rocktype               mud    228
# 68679  surface_rocktype          mudstone   7986
# 68681  surface_rocktype         packstone      2
# 68682  surface_rocktype              peat     85
# 68683  surface_rocktype         pegmatite      1
# 68684  surface_rocktype        peridotite      8
# 68685  surface_rocktype         phonolite      1
# 68686  surface_rocktype       phosphorite    351
# 68687  surface_rocktype          phyllite      9
# 68691  surface_rocktype  quartz monzonite     30
# 68692  surface_rocktype         quartzite    204
# 68694  surface_rocktype          rhyolite    110
# 68695  surface_rocktype              sand   8023
# 68696  surface_rocktype         sandstone  32179
# 68697  surface_rocktype            schist     24
# 68699  surface_rocktype             shale  20856
# 68702  surface_rocktype              silt   7119
# 68703  surface_rocktype         siltstone  16888
# 68704  surface_rocktype             slate      6
# 68706  surface_rocktype           syenite      2
# 68707  surface_rocktype            tephra      3
# 68709  surface_rocktype          tonalite      5
# 68710  surface_rocktype          trachyte     10
# 68711  surface_rocktype        travertine      4
#
#                                                 term_uri
# 68624  http://resource.geosciml.org/classifier/cgi/li...
# 68625  http://resource.geosciml.org/classifier/cgi/li...
# 68627  http://resource.geosciml.org/classifier/cgi/li...
# 68628  http://resource.geosciml.org/classifier/cgi/li...
# 68632  http://resource.geosciml.org/classifier/cgi/li...
# 68633  http://resource.geosciml.org/classifier/cgi/li...
# 68635  http://resource.geosciml.org/classifier/cgi/li...
# 68637  http://resource.geosciml.org/classifier/cgi/li...
# 68638  http://resource.geosciml.org/classifier/cgi/li...
# 68639  http://resource.geosciml.org/classifier/cgi/li...
# 68641  http://resource.geosciml.org/classifier/cgi/li...
# 68643  http://resource.geosciml.org/classifier/cgi/li...
# 68645  http://resource.geosciml.org/classifier/cgi/li...
# 68646  http://resource.geosciml.org/classifier/cgi/li...
# 68647  http://resource.geosciml.org/classifier/cgi/li...
# 68650  http://resource.geosciml.org/classifier/cgi/li...
# 68652  http://resource.geosciml.org/classifier/cgi/li...
# 68654  http://resource.geosciml.org/classifier/cgi/li...
# 68655  http://resource.geosciml.org/classifier/cgi/li...
# 68656  http://resource.geosciml.org/classifier/cgi/li...
# 68657  http://resource.geosciml.org/classifier/cgi/li...
# 68658  http://resource.geosciml.org/classifier/cgi/li...
# 68666  http://resource.geosciml.org/classifier/cgi/li...
# 68667  http://resource.geosciml.org/classifier/cgi/li...
# 68668  http://resource.geosciml.org/classifier/cgi/li...
# 68671  http://resource.geosciml.org/classifier/cgi/li...
# 68675  http://resource.geosciml.org/classifier/cgi/li...
# 68676  http://resource.geosciml.org/classifier/cgi/li...
# 68677  http://resource.geosciml.org/classifier/cgi/li...
# 68678  http://resource.geosciml.org/classifier/cgi/li...
# 68679  http://resource.geosciml.org/classifier/cgi/li...
# 68681  http://resource.geosciml.org/classifier/cgi/li...
# 68682  http://resource.geosciml.org/classifier/cgi/li...
# 68683  http://resource.geosciml.org/classifier/cgi/li...
# 68684  http://resource.geosciml.org/classifier/cgi/li...
# 68685  http://resource.geosciml.org/classifier/cgi/li...
# 68686  http://resource.geosciml.org/classifier/cgi/li...
# 68687  http://resource.geosciml.org/classifier/cgi/li...
# 68691  http://resource.geosciml.org/classifier/cgi/li...
# 68692  http://resource.geosciml.org/classifier/cgi/li...
# 68694  http://resource.geosciml.org/classifier/cgi/li...
# 68695  http://resource.geosciml.org/classifier/cgi/li...
# 68696  http://resource.geosciml.org/classifier/cgi/li...
# 68697  http://resource.geosciml.org/classifier/cgi/li...
# 68699  http://resource.geosciml.org/classifier/cgi/li...
# 68702  http://resource.geosciml.org/classifier/cgi/li...
# 68703  http://resource.geosciml.org/classifier/cgi/li...
# 68704  http://resource.geosciml.org/classifier/cgi/li...
# 68706  http://resource.geosciml.org/classifier/cgi/li...
# 68707  http://resource.geosciml.org/classifier/cgi/li...
# 68709  http://resource.geosciml.org/classifier/cgi/li...
# 68710  http://resource.geosciml.org/classifier/cgi/li...
# 68711  http://resource.geosciml.org/classifier/cgi/li...

# %%
df_count_stats.loc[(df_count_stats.stat_field == "surface_rocktype") & (df_count_stats.term_uri.isnull())]
# Out:
#              stat_field     unique_value  count term_uri
# 68623  surface_rocktype         alluvium   2111     None
# 68626  surface_rocktype        anhydrite     18     None
# 68629  surface_rocktype        argillite     55     None
# 68630  surface_rocktype           arkose    582     None
# 68631  surface_rocktype              ash    352     None
# 68634  surface_rocktype        carbonate    982     None
# 68636  surface_rocktype            chert   1082     None
# 68640  surface_rocktype        colluvium    334     None
# 68642  surface_rocktype          coquina    155     None
# 68644  surface_rocktype          diabase      3     None
# 68648  surface_rocktype        dolostone    607     None
# 68649  surface_rocktype            drift     48     None
# 68651  surface_rocktype          felsite      7     None
# 68653  surface_rocktype            glass     16     None
# 68659  surface_rocktype        graywacke      1     None
# 68660  surface_rocktype             grit     57     None
# 68661  surface_rocktype           gypsum    637     None
# 68662  surface_rocktype           halite      3     None
# 68663  surface_rocktype          igneous    265     None
# 68664  surface_rocktype   iron formation      7     None
# 68665  surface_rocktype        ironstone    103     None
# 68669  surface_rocktype            loess    374     None
# 68670  surface_rocktype            mafic     35     None
# 68672  surface_rocktype             marl    160     None
# 68673  surface_rocktype      metamorphic     24     None
# 68674  surface_rocktype  metasedimentary     25     None
# 68680  surface_rocktype           oolite      5     None
# 68688  surface_rocktype         plutonic     10     None
# 68689  surface_rocktype           pumice     23     None
# 68690  surface_rocktype   quartz arenite      1     None
# 68693  surface_rocktype       rhyodacite      2     None
# 68698  surface_rocktype      sedimentary    493     None
# 68700  surface_rocktype         siderite     38     None
# 68701  surface_rocktype    siliciclastic     31     None
# 68705  surface_rocktype             soil    116     None
# 68708  surface_rocktype             till     38     None
# 68712  surface_rocktype            trona      3     None
# 68713  surface_rocktype             tuff    756     None
# 68714  surface_rocktype         volcanic   4288     None
# 68715  surface_rocktype   volcaniclastic     34     None
# 68716  surface_rocktype       wackestone      3     None
# 68717  surface_rocktype      welded tuff      1     None

# %% [markdown]
# One other potential point of interest from the CRC catalog that represents an untapped resource is the collection of "analysis" files that are linked to cores and cuttings. As part of our data amalgamation, we brought all of these together and can examine what we may have. The following codeblock simply pulls all the document links together and splits out their file extensions so we can pull a quick summary. The collection of documents is really a hodgepodge of various types of things, some of which do represent analytical results from various types of analyses on the samples, but others are simply related artifacts that have been collected and stored over time by the CRC.

# %%
pipeline = [
    {
        u"$project": {
            u"documents": 1.0
        }
    }, 
    {
        u"$unwind": {
            u"path": u"$documents"
        }
    }
]

all_documents = [i for i in mongo_ndc.crc.cores.aggregate(pipeline)]
all_documents.extend([i for i in mongo_ndc.crc.cuttings.aggregate(pipeline)])
df_documents = pd.DataFrame(all_documents)
df_documents["filename"] = df_documents.apply(lambda x: x.documents.split("/")[-1], axis=1)
df_documents["extension"] = df_documents.apply(lambda x: x.documents.split(".")[-1].lower(), axis=1)

for extension, group in df_documents.groupby("extension"):
    print(extension, len(group))
# Out:
#  3
# bmd 154
# bmp 1
# csv 106
# db 3
# doc 57
# docx 119
# emf 28
# hdr 41
# jpg 590
# las 6
# mp4 3
# pdf 8741
# png 34
# ppt 65
# pptx 79
# psd 168
# tif 2141
# tiff 1
# txt 5
# xls 2115
# xlsb 3
# xlsm 178
# xlsx 3406
# xps 2
# zip 72

# %% [markdown]
# Some of these files represent more potentially exploitable material than others. The following codeblocks dump out just the CSV results and then pull up a couple of random examples via Pandas. We could run through a process to try and read as many files as possible from this system, summarizing their contents and adding further metadata to our catalog. Pulling all of what we could extract in this fashion would at least generate some type of master registry of analytes and other properties that could be further examined through semantic alignment work.

# %%
df_documents.loc[df_documents.extension == "csv"]
# Out:
#                             _id  \
# 91     5d87a63b0863b1fac6a7cba1
# 468    5d87a63b0863b1fac6a7cd1c
# 732    5d87a63b0863b1fac6a7cda1
# 752    5d87a63b0863b1fac6a7cdbc
# 1295   5d87a63b0863b1fac6a7cf77
# ...                         ...
# 18073  5d87b7eb0863b1fac6a8c4d7
# 18082  5d87b7eb0863b1fac6a8c4d8
# 18086  5d87b7eb0863b1fac6a8c4e3
# 18088  5d87b7eb0863b1fac6a8c4e4
# 18099  5d87b7eb0863b1fac6a8c514
#
#                                                documents  \
# 91     http://my.usgs.gov/crc-data/core/16106/core_an...
# 468    http://my.usgs.gov/crc-data/core/77935/core_an...
# 732    http://my.usgs.gov/crc-data/prod/core/99399/co...
# 752    http://my.usgs.gov/crc-data/core/78910/core_an...
# 1295   http://my.usgs.gov/crc-data/core/9209/core_ana...
# ...                                                  ...
# 18073  http://my.usgs.gov/crc-data/cutting/80727/cutt...
# 18082  http://my.usgs.gov/crc-data/cutting/80734/cutt...
# 18086  http://my.usgs.gov/crc-data/cutting/80791/cutt...
# 18088  http://my.usgs.gov/crc-data/cutting/80795/cutt...
# 18099  http://my.usgs.gov/crc-data/cutting/104783/cut...
#
#                                            filename extension
# 91               core_analysis_88604_T038data09.csv       csv
# 468          core_analysis_108350_S505XRFData01.csv       csv
# 732     core_analysis_122480_S452BioStratData01.csv       csv
# 752              core_analysis_80308_T481Data01.csv       csv
# 1295             core_analysis_88593_B136data08.csv       csv
# ...                                             ...       ...
# 18073       cutting_analysis_80895_WellHeader47.csv       csv
# 18082       cutting_analysis_80898_WellHeader13.csv       csv
# 18086       cutting_analysis_80902_WellHeader40.csv       csv
# 18088       cutting_analysis_80906_WellHeader17.csv       csv
# 18099  cutting_analysis_104785_HH01823XRFData01.csv       csv
#
# [106 rows x 4 columns]

# %% [markdown]
# This example, picked at random, indicates a couple of problems often encountered with reading CSV data - dealing with different text encoding from CSV generated from Windows operating systems, in particular, and finding the actual data table within what may be a mixed bag of header information. There are various messy data tools that help to deal with some of these problems. The Excel files are sometimes even more challenging to deal with as they often contain a whole lot of additional metadata about the data file structured in various ways that can be difficult to handle without very specific software.

# %%
pd.read_csv(df_documents.iloc[12264]["documents"], encoding='latin1')
# Out:
#    Sample data for well: 1 McTuillin Federal B703 Unnamed: 1 Unnamed: 2  \
# 0                                           depth       type    analyst
# 1                                             NaN        NaN        NaN
# 2                                             NaN        NaN        NaN
# 3                                          4824.7         CO       JPGF
# 4                                            4827         CO       JPGF
# 5                                          4828.3         CO       JPGF
# 6                                          4838.2         CO       JPGF
# 7                                          4844.7         CO       JPGF
# 8                                            4849         CO       JPGF
# 9                                          4851.3         CO       JPGF
# 10                                         4852.6         CO       JPGF
# 11                                         4852.7         CO       JPGF
# 12                                           4855         CO       JPGF
# 13                                           4867         CO       JPGF
# 14                                         4876.6         CO       JPGF
# 15                                         4882.8         CO       JPGF
# 16                                           4890         CO       JPGF
#
#    Unnamed: 3        Unnamed: 4         Unnamed: 5          Unnamed: 6  \
# 0       label  Bisaccate pollen  Chatangiella spp.  Circulodinium spp.
# 1         NaN                MI                 DC                  DC
# 2         NaN               NaN                NaN                 NaN
# 3         NaN                32                  2                   1
# 4         NaN                61                  4                 NaN
# 5         NaN                38                  3                 NaN
# 6         NaN                61                  5                 NaN
# 7         NaN                54                  5                   2
# 8         NaN                82                  2                 NaN
# 9         NaN                92                  2                   1
# 10        NaN                53                  3                   2
# 11        NaN                51                  3                  20
# 12        NaN                57                  1                  12
# 13        NaN                28                  4                  14
# 14        NaN                15                  4                   2
# 15        NaN                28                NaN                   6
# 16        NaN                24                NaN                   7
#
#                   Unnamed: 7             Unnamed: 8              Unnamed: 9  \
# 0   Circulodinium distinctum  Cribroperidinium spp.  Exochosphaeridium spp.
# 1                         DC                     DC                      DC
# 2                        NaN                    NaN                     NaN
# 3                          3                      +                       1
# 4                          1                      1                       1
# 5                          1                      1                     NaN
# 6                          1                      3                     NaN
# 7                          4                      4                     NaN
# 8                          +                    NaN                       1
# 9                          3                      1                       1
# 10                       NaN                      1                       2
# 11                         5                      4                       3
# 12                         4                      6                       1
# 13                         4                      3                       2
# 14                       NaN                      2                       2
# 15                         4                      2                       +
# 16                       NaN                      2                       1
#
#     ...                Unnamed: 126            Unnamed: 127  \
# 0   ...  Laevigatosporites gracilis  Pterospermella zonaria
# 1   ...                          MI                      AL
# 2   ...                         NaN                     NaN
# 3   ...                         NaN                     NaN
# 4   ...                         NaN                     NaN
# 5   ...                         NaN                     NaN
# 6   ...                         NaN                     NaN
# 7   ...                         NaN                     NaN
# 8   ...                         NaN                     NaN
# 9   ...                         NaN                     NaN
# 10  ...                         NaN                     NaN
# 11  ...                         NaN                     NaN
# 12  ...                         NaN                     NaN
# 13  ...                           1                       1
# 14  ...                         NaN                     NaN
# 15  ...                         NaN                     NaN
# 16  ...                         NaN                     NaN
#
#                 Unnamed: 128            Unnamed: 129  \
# 0   Dinopterygium konradense  Florentinia cooksoniae
# 1                         DC                      DC
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# 5                        NaN                     NaN
# 6                        NaN                     NaN
# 7                        NaN                     NaN
# 8                        NaN                     NaN
# 9                        NaN                     NaN
# 10                       NaN                     NaN
# 11                       NaN                     NaN
# 12                       NaN                     NaN
# 13                       NaN                     NaN
# 14                         +                       +
# 15                       NaN                     NaN
# 16                       NaN                       1
#
#                   Unnamed: 130        Unnamed: 131              Unnamed: 132  \
# 0   Genus A sp. 1 Upshaw, 1964  Klukisporites spp.  Isabelidinium? amphiatum
# 1                           MI                  MI                        DC
# 2                          NaN                 NaN                       NaN
# 3                          NaN                 NaN                       NaN
# 4                          NaN                 NaN                       NaN
# 5                          NaN                 NaN                       NaN
# 6                          NaN                 NaN                       NaN
# 7                          NaN                 NaN                       NaN
# 8                          NaN                 NaN                       NaN
# 9                          NaN                 NaN                       NaN
# 10                         NaN                 NaN                       NaN
# 11                         NaN                 NaN                       NaN
# 12                         NaN                 NaN                       NaN
# 13                         NaN                 NaN                       NaN
# 14                           1                   1                       NaN
# 15                         NaN                 NaN                         +
# 16                         NaN                 NaN                       NaN
#
#                   Unnamed: 133                   Unnamed: 134  \
# 0   Rouseisporites reticulatus  Scriniodinium `simplicum` ROB
# 1                           MI                             DC
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
# 5                          NaN                            NaN
# 6                          NaN                            NaN
# 7                          NaN                            NaN
# 8                          NaN                            NaN
# 9                          NaN                            NaN
# 10                         NaN                            NaN
# 11                         NaN                            NaN
# 12                         NaN                            NaN
# 13                         NaN                            NaN
# 14                         NaN                            NaN
# 15                           +                              +
# 16                         NaN                              +
#
#               Unnamed: 135
# 0   ?Florentinia mantellii
# 1                       DC
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                       1
#
# [17 rows x 136 columns]

# %% [markdown]
# This example is reasonably typical of geochemical analyses where we have some identifiers that are likely not referenced in the actual CRC metadata, depth values where subsamples were taken, and analyte names that need to be deciphered.

# %%
pd.read_csv(df_documents.iloc[3537]["documents"])
# Out:
#         Sample Sample_id1      Sample_id2  Depth_ft  C_pct  H_pct  N_pct  \
# 0  E150503-001  HP7-149.5     7 HP Beaver     149.5  57.45   5.26   1.93
# 1  E150503-002  HP2-242.9     2 HP Potter     242.9  53.58   4.92   1.60
# 2  E150503-003    BN-4536  1-3 BN Coastal    4536.0  64.53   5.97   2.16
# 3  E150503-004  HP3-272.5      3 HP Heath     272.5  56.64   5.23   1.88
#
#     H/C   N/C  tot_Kerogen_S_pct  tot_Kerogen_S/C  Pyritic_Fe_pct  \
# 0  1.09  0.03               5.54             0.04            2.25
# 1  1.09  0.03               5.22             0.04            1.76
# 2  1.10  0.03               4.44             0.03            2.28
# 3  1.10  0.03               6.90             0.05            3.02
#
#    Pyritic_S_pct  Organic_S_pct  Organic_S/C
# 0           2.58           2.96         0.02
# 1           2.02           3.20         0.02
# 2           2.62           1.82         0.01
# 3           3.47           3.43         0.02
